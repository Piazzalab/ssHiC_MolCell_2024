# %%
from hicstuff import hicstuff
import pandas as pd
import hicstuff.view as hcv
import hicstuff.io as hio
import numpy as np
import sys
import numpy as np

todense = lambda x: hcv.sparse_to_dense(x, remove_diag=False)

# %% [markdown]
# Script de Gael et Vittore qui utilise la fonction todense de hicstuff
# En input il faut une matrice (...mat.tsv) deja binnee en kb avec la fonction hicstuff rebin

# %% [markdown]
# #Editer et copier dans le terminal si besoin
#
#
# hicstuff rebin -b 1kb -f /mnt/e/Science/HiC/Contact_files/Sparse/fragments_list_W303_710_DpnIIHinfI.txt -c /mnt/e/Science/HiC/Contact_files/Sparse/info_contigs_W303_710_DpnIIHinfI.txt /mnt/e/Science/HiC/Contact_files/Sparse/HB27_1_2_merged_trimmed.txt /mnt/e/Science/HiC/Contact_files/Rebin/HB27_1_2_merged_1kb

# %% [markdown]
# Utilise hicstuff ici: le chargement de la matrice + conversion prend quelques minutes max sur un PC.
#
# Les coordonnees des chromosomes sont donnes par le fichier frag.tsv genere par hicstuff rebin

# %%
##change the input directory for S288c or other genomes

input_dir = "/mnt/e/Science/ssHiC/Contact_files/Rebin/S288c/"  # 1st argument: sparce matrix file name and path
#input_dir = "/mnt/e/Science/HiC/Contact_files/Rebin/S288c/"  # 1st argument: sparce matrix file name and path
output_dir = "/mnt/e/Science/ssHiC/Contact_files/Dense/S288c/"  # 2nd argument: dense matrix file name and path
#output_dir = "/mnt/e/Science/HiC/Contact_files/Dense/S288c/"  # 2nd argument: dense matrix file name and path

samples = [#"AD162_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          #"AD210_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          #"AD211_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          #"AD233_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          #"AD234_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD235_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD236_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD237_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD238_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD239_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD240_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD241_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD242_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD243_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD244_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD245_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD246_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD247_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
          "AD248_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD257_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD258_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD259_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD260_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD261_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD289_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD290_S288c_DSB_LY_capture_artificial_v8_cutsite_q20_PCRfree",
           "AD291_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD292_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD293_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD294_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD295_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD296_S288c_DSB_LY_capture_artificial_v8_cutsite_q20_PCRfree",
           "AD297_S288c_DSB_LY_capture_artificial_v8_cutsite_q20_PCRfree",
           "AD298_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD299_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD300_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD301_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD302_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD342_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD343_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD344_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD345_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD346_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD347_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD356_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD357_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD358_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD359_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD360_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD361_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD401_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD402_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD403_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD404_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD405_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD406_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD407_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD412_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD413_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD414_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD432_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD433_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD433m_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD446_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD447_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD448_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD449_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD450_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD451_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD452_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD453_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD454_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD455_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD456_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD457_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD458_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD459_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD460_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD461_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD462_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD463_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD464_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD465_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD473_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD474_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD475_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD476_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD477_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD478_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD479_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD480_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD481_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD488_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD489_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD490_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD491_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD492_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD493_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD542_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD543_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD544_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD545_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD546_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD547_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD548_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD549_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD550_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD551_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD552_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD553_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD554_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD555_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD570_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD571_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD572_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD573_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD574_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD575_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD576_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD577_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD584_demixed_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD585_demixed_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD586_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD587_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD588_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD589_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD590_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD591_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD592_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree",
           "AD593_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree"
]

# %%
chrom_intersect_1 = ["chr5"] #specifies the primary chromosome(s) to make intersection
chrom_intersect_2 = ["chr2", "chr3"] #specifies the secondary chromosome(s) to make intersection
chromlist = ["chr2", "chr3", "chr4", "chr5", "chr11", "chr12"] #chromosomes to extract for intra analysis

for sample in samples:
    frags = pd.read_csv(str(input_dir + sample + "_1kb.frags.tsv"), sep = "\t")
    #frags = pd.read_csv(str(input_dir + sample + "_1kb.frag.tsv"), sep = "\t")
    
    sparse_mat = hio.load_sparse_matrix(str(input_dir + sample + "_1kb.mat.tsv"))
    dense_mat = todense(sparse_mat)
    dense_mat = dense_mat.astype(int) # https://docs.scipy.org/doc/numpy/reference/generated/numpy.ndarray.astype.html
    np.savetxt(str(output_dir + sample + "_dense_1kb.mat.csv"), dense_mat, fmt="%i")

    #Export individual chromosomes
    for chrom in chromlist:

        start = min(frags[(frags["chrom"]== chrom)].index.values)
        stop = max(frags[(frags["chrom"]== chrom)].index.values)

        dense_mat2 = dense_mat[start:stop,start:stop]
        np.savetxt(str(output_dir + sample + "_" + str(chrom) + "_dense_1kb.mat.csv"), dense_mat2, fmt="%i")
    
    #export chromosome intersections    
    for chrom in chrom_intersect_1:
        start = min(frags[(frags["chrom"]== chrom)].index.values)
        stop = max(frags[(frags["chrom"]== chrom)].index.values)
        
        for chrom_alt in chrom_intersect_2:
            start_alt = min(frags[(frags["chrom"]== chrom_alt)].index.values)
            stop_alt = max(frags[(frags["chrom"]== chrom_alt)].index.values)
            dense_mat2 = dense_mat[start_alt:stop_alt,start:stop]
            np.savetxt(str(output_dir + sample + "_" + str(chrom_alt) + "_" + str(chrom) + "_dense_1kb.mat.csv"), dense_mat2, fmt="%i")
    
    #remove the 2-micron and the mitochondria
    start = 0
    stop = max(frags[(frags["chrom"]== "chr16")].index.values)
    dense_mat2 = dense_mat[start:stop,start:stop]
    np.savetxt(str(output_dir + sample + "_chrs_dense_1kb.mat.csv"), dense_mat2, fmt="%i")
    print(str(sample) + " done")
# Out:
# AD235_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD236_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD237_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD238_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD239_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD240_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD241_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD242_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD243_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD244_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD245_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD246_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD247_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# AD248_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree done
# ...
