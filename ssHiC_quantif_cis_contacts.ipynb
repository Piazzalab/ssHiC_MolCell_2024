# %% [markdown]
# written by chatGPT. The code quantify the contacts made by each probe with a given chromosomal region. It uses the output of the ssHiC pipeline: a table with 3 columns specifying chr, chr_coord, and genome_coord, and the rest of the column being the contact made by each targeted fragments

# %%
import pandas as pd
import numpy as np

# %%
input_dir_contacts = "/mnt/e/Science/ssHiC/Samples/"
output_dir = "/mnt/d/Science/Owncloud/Experiments/Capture/Analysis/Intra_Inter_Cis_Coverage_Chr/cis_side_specific/"

suffix = "_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree"
reference_table = pd.read_csv(str(output_dir) + "_ssHiC_probe_location_and_side.tsv", sep="\t")

samples = ["AD206", "AD207", "AD208", "AD209", "AD212", "AD213"] #to do
samples = ["AD162",  "AD210", "AD211",  "AD233", "AD234", "AD235", "AD236", 
           "AD237", "AD238", "AD239", "AD240", "AD241", "AD242", "AD243", "AD244", "AD245", "AD246", 
           "AD247", "AD248", "AD257", "AD258", "AD259", "AD260", "AD289", "AD290", "AD291", "AD292", 
           "AD293", "AD294", "AD295", "AD296", "AD297", "AD298", "AD299", "AD300", 
           "AD301", "AD302", "AD342", "AD343", "AD344", "AD345", "AD346", "AD347", "AD401", "AD402", 
           "AD403", "AD404", "AD405", "AD406", "AD407", "AD412", "AD413", "AD414", "AD432", "AD433m",
           "AD446", "AD447", "AD448", "AD449", "AD450", "AD451", "AD452", "AD453", "AD454", "AD455",
           "AD456", "AD457", "AD458", "AD459", "AD460", "AD461", "AD462", "AD463", "AD464", "AD465",
           "AD473", "AD474", "AD475", "AD476", "AD477", "AD478", "AD479", "AD480", "AD481", "AD488",
           "AD489", "AD490", "AD491", "AD492", "AD493", "AD542", "AD543", "AD544", "AD545", "AD546",
           "AD547", "AD548", "AD549", "AD550", "AD551", "AD552", "AD553", "AD554", "AD555", "AD570",
           "AD571", "AD572", "AD573", "AD574", "AD575", "AD576", "AD577", "AD586", "AD587", "AD588",
           "AD589", "AD590", "AD591", "AD592", "AD593"]


interval = 25000 #in bp

# %% [markdown]
# This function calculates the sum of contacts immediately in cis and on the cognate side of a ssDNA probe, within a given interval. For dsDNA probe it calculate contacts in half the interval on both side (20 kb on one side for ssDNA gives 10 kb on each side for dsDNA)

# %%
for sample in samples:
    path = str(str(input_dir_contacts) + str(sample) + str(suffix) + "/")
    sshic_contacts = pd.read_csv(str(path) +  "/classic/" +
                                 str(sample) + str(suffix) +
                                 "_1kb_profile_frequencies.tsv", sep="\t")
    results = np.array([])
    rows = np.array([])
    
    for col in sshic_contacts.columns[3:31]:
        # Get the coordinate and chromosome of the fragment
        fragment_info = reference_table.loc[reference_table['fragment'] == int(col)]
        fragment_coord = fragment_info['coordinate'].values[0]
        fragment_chromosome = fragment_info['chr'].values[0]
        side = fragment_info['side'].values[0]

        #print(fragment_chromosome)
        # Determine the start and end coordinates of the interval based on the side
        if side == 'left':
            interval_start = max(fragment_coord - interval, 0)  # Ensure not to go below 0
            interval_end = fragment_coord
        elif side == 'right':
            # Get the maximum coordinate on the chromosome
            max_chromosome_coord = sshic_contacts.loc[sshic_contacts['chr'] == fragment_chromosome, 'chr_bins'].max()
            interval_start = fragment_coord
            interval_end = min(fragment_coord + interval, max_chromosome_coord)  # Ensure not to exceed chromosome length
        elif side == 'na':
            max_chromosome_coord = sshic_contacts.loc[sshic_contacts['chr'] == fragment_chromosome, 'chr_bins'].max()
            interval_start = max(fragment_coord - (interval/2), 0) 
            interval_end = min(fragment_coord + (interval/2), max_chromosome_coord) 
        else:
            raise ValueError("Side must be 'left' or 'right'")

        # Filter the sshic_contacts table for the specified interval and chromosome
        contacts_within_interval = sshic_contacts[(sshic_contacts['chr'] == fragment_chromosome) &
                                                  (sshic_contacts['chr_bins'] >= interval_start) &
                                                  (sshic_contacts['chr_bins'] <= interval_end)]

        # Sum the contacts for each fragment
        sum_contacts = contacts_within_interval[[col]].sum()
        results = np.append(results, sum_contacts.iloc[0])
        rows = np.append(rows, col)

    results = pd.DataFrame({'Fragment': rows, str('Cis' + str(interval)): results})  
    #results = results.transpose()
    results.to_csv(str(output_dir) + str(sample) + str(suffix) + "_side_specific_cis_" + str(interval) + ".tsv", sep="\t")
    
    
    print(str(sample) + str(suffix) + " is done")
# Out:
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD162_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD210_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD211_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD233_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD234_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD235_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD236_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD237_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD238_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD239_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD240_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD241_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD242_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD243_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD244_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD245_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD246_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD247_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD248_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD257_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD258_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD259_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD260_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD289_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD290_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD291_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD292_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD293_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD294_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD295_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD296_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD297_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD298_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD299_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD300_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD301_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD302_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD342_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD343_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD344_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD345_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD346_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD347_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD401_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD402_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD403_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD404_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD405_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD406_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD407_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD412_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD413_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD414_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD432_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD433m_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD446_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD447_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD448_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD449_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD450_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD451_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD452_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD453_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD454_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD455_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD456_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD457_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD458_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD459_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD460_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD461_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD462_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD463_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD464_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD465_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD473_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD474_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD475_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD476_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD477_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD478_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD479_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD480_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD481_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD488_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD489_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD490_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD491_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD492_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD493_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD542_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD543_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD544_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD545_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD546_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD547_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD548_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD549_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD550_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD551_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD552_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD553_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD554_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD555_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD570_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD571_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD572_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD573_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD574_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD575_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD576_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD577_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD586_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD587_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD588_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD589_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD590_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# left
# right
# right
# right
# right
# right
# right
# right
# right
# right
# na
# na
# na
# na
# na
# na
# na
# AD591_sub4M_S288c_DSB_LY_Capture_artificial_v8_cutsite_q20_PCRfree is done

# %%
# Define a function to calculate the sum of contacts within a given interval for each fragment
interval = 25000
results = np.array([])
rows = np.array([])

for col in sshic_contacts.columns[3:31]:
    # Get the coordinate and chromosome of the fragment
    fragment_info = reference_table.loc[reference_table['fragment'] == int(col)]
    fragment_coord = fragment_info['coordinate'].values[0]
    fragment_chromosome = fragment_info['chr'].values[0]
    #print(fragment_chromosome)
    # Determine the start and end coordinates of the interval based on the side
    if side == 'left':
        interval_start = max(fragment_coord - interval, 0)  # Ensure not to go below 0
        interval_end = fragment_coord
    elif side == 'right':
        # Get the maximum coordinate on the chromosome
        max_chromosome_coord = sshic_contacts.loc[sshic_contacts['chr'] == fragment_chromosome, 'chr_bins'].max()
        interval_start = fragment_coord
        interval_end = min(fragment_coord + interval, max_chromosome_coord)  # Ensure not to exceed chromosome length
    elif side == 'na':
        max_chromosome_coord = sshic_contacts.loc[sshic_contacts['chr'] == fragment_chromosome, 'chr_bins'].max()
        interval_start = max(fragment_coord - (interval/2), 0) 
        interval_end = min(fragment_coord + (interval/2), max_chromosome_coord) 
    else:
        raise ValueError("Side must be 'left' or 'right'")
    
    # Filter the sshic_contacts table for the specified interval and chromosome
    contacts_within_interval = sshic_contacts[(sshic_contacts['chr'] == fragment_chromosome) &
                                              (sshic_contacts['chr_bins'] >= interval_start) &
                                              (sshic_contacts['chr_bins'] <= interval_end)]
    
    # Sum the contacts for each fragment
    sum_contacts = contacts_within_interval[[col]].sum()
    results = np.append(results, sum_contacts.iloc[0])
    rows = np.append(rows, col)

results = pd.DataFrame({'Fragment': rows, str('Cis' + str(interval)): results})  
#results = results.transpose()

print(results)
# Out:
#    Fragment  Cis25000
# 0     74840  0.413515
# 1     74841  0.410891
# 2     74842  0.351333
# 3     74843  0.116667
# 4     74844  0.173797
# 5     74845  0.085053
# 6     74846  0.000000
# 7     74847  0.070471
# 8     74848  0.063274
# 9     74849  0.051383
# 10    74850  0.033209
# 11    74851  0.000000
# 12    74852  0.020833
# 13    74853  0.035398
# 14    74854  0.055941
# 15    74855  0.036323
# 16    74856  0.036421
# 17    74857  0.207331
# 18    74858  0.022223
# 19    74859  0.083333
# 20    74860  0.000000
# 21     5315  0.293364
# 22     8579  0.260059
# 23    30726  0.307537
# 24    32518  0.271096
# 25    38840  0.260386
# 26    65856  0.297147
# 27    68265  0.388481
